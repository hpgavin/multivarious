# %%
# !pip install -e .
# Out:
# Obtaining file:///Users/pjaram84/Desktop/multivarious/multivarious_fork
#   Installing build dependencies ... one
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for multivarious (pyproject.toml) ... done
#   Created wheel for multivarious: filename=multivarious-0.1-0.editable-py3-none-any.whl size=2870 sha256=4247088559ee768427a6d5a7c4819f3b89d9efc43499cf69bdf6228343841ad2
#   Stored in directory: /private/var/folders/d4/091mk2ld0z77zrqkvzvgfyhc0000gn/T/pip-ephem-wheel-cache-daau_63p/wheels/57/41/37/3699a9120d81fb8e8d4a872226e7648f857c26f6238bd8a613
# Successfully built multivarious
# ...
#   Attempting uninstall: multivarious
#     Found existing installation: multivarious 0.1
#     Uninstalling multivarious-0.1:
#       Successfully uninstalled multivarious-0.1
# ...

# %%
import sys
print(sys.executable)
# Out:
# /Users/pjaram84/anaconda3/bin/python3

# %%
import sys
sys.executable
# Out:
# '/Users/pjaram84/anaconda3/bin/python3'

# %%
import sys
sys.path.append("/Users/pjaram84/Desktop/multivarious/multivarious_fork/src")

import sys
for p in sys.path:
    print(p)
# Out:
# /Users/pjaram84/anaconda3/lib/python313.zip
# /Users/pjaram84/anaconda3/lib/python3.13
# /Users/pjaram84/anaconda3/lib/python3.13/lib-dynload
#
# /Users/pjaram84/anaconda3/lib/python3.13/site-packages
# /Users/pjaram84/anaconda3/lib/python3.13/site-packages/aeosa
# /Users/pjaram84/Desktop/multivarious/multivarious_fork/src

# %%
import sys
for p in sys.path:
    print(p)
# Out:
# /Users/pjaram84/anaconda3/lib/python313.zip
# /Users/pjaram84/anaconda3/lib/python3.13
# /Users/pjaram84/anaconda3/lib/python3.13/lib-dynload
#
# /Users/pjaram84/anaconda3/lib/python3.13/site-packages
# /Users/pjaram84/anaconda3/lib/python3.13/site-packages/aeosa

# %%
import sys
sys.path.append("/Users/pjaram84/Desktop/multivarious/multivarious_fork/src")

# %%
from multivarious.optimization import ors
from multivarious.optimization import sqp
from multivarious.optimization import nms

print("opt algorithms import worked!")
# Out:
# opt algorithms import worked!
